# %%
# Geometry of Cell States Across Representations (PCA, Autoencoder, scVI)

## Scientific Question
How does the geometric organization of cell states differ between disease and treatment conditions, and which geometric conclusions are robust to representation choice?

## Overview
In this notebook, we analyze single-cell RNA-seq data from progressive multiple sclerosis neural stem cells using three representation learning approaches:
- Linear (PCA)
- Nonlinear deterministic (Autoencoder)
- Probabilistic, noise-aware (scVI)

For each representation, we quantify cell-state geometry using pairwise distances, dispersion, compactness, and distance distributions, and compare disease (DMSO) versus treatment (ABT) conditions.

## Goal
To assess whether disease-associated expansion and heterogeneity of cell-state space persist across fundamentally different representation assumptions.


from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/ms_singlecell/data
# Out:
# adata_abt_n   HD_ABT_filtered.h5ad   PMS_ABT_filtered.h5ad
# adata_dmso_n  HD_DMSO_filtered.h5ad  PMS_DMSO_filtered.h5ad

# %%
# !pip install scanpy
# Out:
# Collecting scanpy
#   Downloading scanpy-1.11.5-py3-none-any.whl.metadata (9.3 kB)
# Collecting anndata>=0.8 (from scanpy)
#   Downloading anndata-0.12.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: h5py>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from scanpy) (3.15.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from scanpy) (1.5.3)
# Collecting legacy-api-wrap>=1.4.1 (from scanpy)
#   Downloading legacy_api_wrap-1.5-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: matplotlib>=3.7.5 in /usr/local/lib/python3.12/dist-packages (from scanpy) (3.10.0)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from scanpy) (8.4.0)
# Requirement already satisfied: networkx>=2.7.1 in /usr/local/lib/python3.12/dist-packages (from scanpy) (3.6.1)
# Requirement already satisfied: numba!=0.62.0rc1,>=0.57.1 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.60.0)
# Requirement already satisfied: numpy>=1.24.1 in /usr/local/lib/python3.12/dist-packages (from scanpy) (2.0.2)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from scanpy) (25.0)
# Requirement already satisfied: pandas>=1.5.3 in /usr/local/lib/python3.12/dist-packages (from scanpy) (2.2.2)
# Requirement already satisfied: patsy!=1.0.0 in /usr/local/lib/python3.12/dist-packages (from scanpy) (1.0.2)
# Requirement already satisfied: pynndescent>=0.5.13 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.5.13)
# Requirement already satisfied: scikit-learn>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from scanpy) (1.6.1)
# Requirement already satisfied: scipy>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from scanpy) (1.16.3)
# Requirement already satisfied: seaborn>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.13.2)
# Collecting session-info2 (from scanpy)
#   Downloading session_info2-0.3-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: statsmodels>=0.14.5 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.14.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from scanpy) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from scanpy) (4.15.0)
# Requirement already satisfied: umap-learn>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.5.9.post2)
# Collecting array-api-compat>=1.7.1 (from anndata>=0.8->scanpy)
#   Downloading array_api_compat-1.13.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting zarr!=3.0.*,>=2.18.7 (from anndata>=0.8->scanpy)
#   Downloading zarr-3.1.5-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba!=0.62.0rc1,>=0.57.1->scanpy) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.3->scanpy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.3->scanpy) (2025.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.3->scanpy) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7.5->scanpy) (1.17.0)
# Collecting donfig>=0.8 (from zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy)
#   Downloading donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: google-crc32c>=1.5 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy) (1.7.1)
# Collecting numcodecs>=0.14 (from zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy)
#   Downloading numcodecs-0.16.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from donfig>=0.8->zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy) (6.0.3)
# Downloading scanpy-1.11.5-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 102.1 MB/s eta 0:00:00
# Downloading anndata-0.12.7-py3-none-any.whl (174 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.2/174.2 kB 18.2 MB/s eta 0:00:00
# Downloading legacy_api_wrap-1.5-py3-none-any.whl (10 kB)
# Downloading session_info2-0.3-py3-none-any.whl (17 kB)
# Downloading array_api_compat-1.13.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.6/58.6 kB 5.8 MB/s eta 0:00:00
# Downloading zarr-3.1.5-py3-none-any.whl (284 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.1/284.1 kB 28.0 MB/s eta 0:00:00
# Downloading donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Downloading numcodecs-0.16.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 144.8 MB/s eta 0:00:00
# Installing collected packages: session-info2, numcodecs, legacy-api-wrap, donfig, array-api-compat, zarr, anndata, scanpy
# Successfully installed anndata-0.12.7 array-api-compat-1.13.0 donfig-0.8.1.post1 legacy-api-wrap-1.5 numcodecs-0.16.5 scanpy-1.11.5 session-info2-0.3 zarr-3.1.5

# %%
import scanpy as sc

base = "/content/drive/MyDrive/ms_singlecell/data/"

adata_abt_n  = sc.read_h5ad(f"{base}/adata_abt_n")

# %%
import scanpy as sc

base = "/content/drive/MyDrive/ms_singlecell/data/"

adata_dmso_n  = sc.read_h5ad(f"{base}/adata_dmso_n")

# %%
adata_dmso_n.write("adata_dmso_frozen.h5ad")
adata_abt_n.write("adata_abt_frozen.h5ad")

# %%
print(adata_dmso_n.shape)
print(adata_abt_n.shape)

print((adata_dmso_n.var_names == adata_abt_n.var_names).all())
# Out:
# (3281, 23494)
# (8987, 23494)
# True

# %%
adata_tmp = adata_dmso_n.copy()

# %%
print("DMSO shape:", adata_dmso_n.shape)
print("ABT  shape:", adata_abt_n.shape)
print("Genes aligned:",
      (adata_dmso_n.var_names == adata_abt_n.var_names).all())
# Out:
# DMSO shape: (3281, 23494)
# ABT  shape: (8987, 23494)
# Genes aligned: True

# %%
import scanpy as sc

sc.pp.scale(adata_dmso_n, max_value =10)
sc.pp.scale(adata_abt_n, max_value =10)
# Out:
# /usr/lib/python3.12/functools.py:912: UserWarning: zero-centering a sparse array/matrix densifies it.
#   return dispatch(args[0].__class__)(*args, **kw)
# /usr/lib/python3.12/functools.py:912: UserWarning: zero-centering a sparse array/matrix densifies it.
#   return dispatch(args[0].__class__)(*args, **kw)

# %%
n_pcs = 20

sc.tl.pca(adata_dmso_n, n_comps=n_pcs, svd_solver="arpack")
sc.tl.pca(adata_abt_n,  n_comps=n_pcs, svd_solver="arpack")

# %%
print("DMSO variance explained (first 10 PCs):")
print(adata_dmso_n.uns["pca"]["variance_ratio"][:10])

print("\nABT variance explained (first 10 PCs):")
print(adata_abt_n.uns["pca"]["variance_ratio"][:10])
# Out:
# DMSO variance explained (first 10 PCs):
# [0.06545809 0.01281095 0.00512672 0.00359378 0.00265931 0.00239149
#  0.0022202  0.00209686 0.00161917 0.0015904 ]
#
# ABT variance explained (first 10 PCs):
# [0.02668111 0.0133332  0.00780506 0.00372046 0.0027715  0.00224595
#  0.00179549 0.00158333 0.00127058 0.00120427]

# %%
import numpy as np

X_dmso_pca = adata_dmso_n.obsm["X_pca"][:, :n_pcs]
X_abt_pca  = adata_abt_n.obsm["X_pca"][:,  :n_pcs]

print("PCA shapes:", X_dmso_pca.shape, X_abt_pca.shape)
# Out:
# PCA shapes: (3281, 20) (8987, 20)

# %%
assert X_dmso_pca.shape[1] == n_pcs
assert X_abt_pca.shape[1]  == n_pcs
assert np.all(np.isfinite(X_dmso_pca))
assert np.all(np.isfinite(X_abt_pca))

# %%
from scipy.spatial.distance import pdist

# Pairwise distances within each condition
dist_dmso = pdist(X_dmso_pca, metric="euclidean")
dist_abt  = pdist(X_abt_pca,  metric="euclidean")

print("DMSO distances:", dist_dmso.shape)
print("ABT  distances:", dist_abt.shape)
# Out:
# DMSO distances: (5380840,)
# ABT  distances: (40378591,)

# %%
dispersion_dmso = dist_dmso.mean()
dispersion_abt  = dist_abt.mean()

print("DMSO dispersion:", dispersion_dmso)
print("ABT  dispersion:", dispersion_abt)
# Out:
# DMSO dispersion: 55.32548561162718
# ABT  dispersion: 47.68096583151013

# %%
from sklearn.neighbors import NearestNeighbors

def compute_compactness(X, k=10):
    nbrs = NearestNeighbors(n_neighbors=k+1).fit(X)
    distances, _ = nbrs.kneighbors(X)
    # exclude self-distance (0)
    return distances[:, 1:].mean()

compact_dmso = compute_compactness(X_dmso_pca, k=10)
compact_abt  = compute_compactness(X_abt_pca,  k=10)

print("DMSO compactness:", compact_dmso)
print("ABT  compactness:", compact_abt)
# Out:
# DMSO compactness: 13.371022090770893
# ABT  compactness: 13.436358024668904

# %%
print("DMSO mean/std:", dist_dmso.mean(), dist_dmso.std())
print("ABT  mean/std:", dist_abt.mean(),  dist_abt.std())
# Out:
# DMSO mean/std: 55.32548561162718 29.858979921883307
# ABT  mean/std: 47.68096583151013 15.487923299258153

# %%
# !pip install scvi-tools
# Out:
# Collecting scvi-tools
#   Downloading scvi_tools-1.4.1-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: anndata>=0.11 in /usr/local/lib/python3.12/dist-packages (from scvi-tools) (0.12.7)
# Collecting docrep>=0.3.2 (from scvi-tools)
#   Downloading docrep-0.3.2.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Collecting lightning>=2.0 (from scvi-tools)
#   Downloading lightning-2.6.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 4.0 MB/s eta 0:00:00
# Collecting ml-collections (from scvi-tools)
#   Downloading ml_collections-1.1.0-py3-none-any.whl.metadata (22 kB)
# Collecting mudata (from scvi-tools)
#   Downloading mudata-0.3.2-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: numba>=0.60.0 in /usr/local/lib/python3.12/dist-packages (from scvi-tools) (0.60.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from scvi-tools) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from scvi-tools) (2.2.2)
# Collecting pyro-ppl (from scvi-tools)
#   Downloading pyro_ppl-1.9.1-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from scvi-tools) (13.9.4)
# Requirement already satisfied: scanpy>=1.10 in /usr/local/lib/python3.12/dist-packages (from scanpy[skmisc]>=1.10->scvi-tools) (1.11.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from scvi-tools) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from scvi-tools) (1.16.3)
# Collecting sparse>=0.14.0 (from scvi-tools)
#   Downloading sparse-0.17.0-py2.py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.12/dist-packages (from scvi-tools) (2.19.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from scvi-tools) (2.9.0+cu126)
# Collecting torchmetrics (from scvi-tools)
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from scvi-tools) (4.67.1)
# Requirement already satisfied: xarray in /usr/local/lib/python3.12/dist-packages (from scvi-tools) (2025.12.0)
# Requirement already satisfied: array-api-compat>=1.7.1 in /usr/local/lib/python3.12/dist-packages (from anndata>=0.11->scvi-tools) (1.13.0)
# Requirement already satisfied: h5py>=3.8 in /usr/local/lib/python3.12/dist-packages (from anndata>=0.11->scvi-tools) (3.15.1)
# Requirement already satisfied: legacy-api-wrap in /usr/local/lib/python3.12/dist-packages (from anndata>=0.11->scvi-tools) (1.5)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from anndata>=0.11->scvi-tools) (8.4.0)
# Requirement already satisfied: packaging>=24.2 in /usr/local/lib/python3.12/dist-packages (from anndata>=0.11->scvi-tools) (25.0)
# Requirement already satisfied: zarr!=3.0.*,>=2.18.7 in /usr/local/lib/python3.12/dist-packages (from anndata>=0.11->scvi-tools) (3.1.5)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from docrep>=0.3.2->scvi-tools) (1.17.0)
# Requirement already satisfied: PyYAML<8.0,>5.4 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0->scvi-tools) (6.0.3)
# Requirement already satisfied: fsspec<2027.0,>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0->scvi-tools) (2025.3.0)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning>=2.0->scvi-tools)
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: typing-extensions<6.0,>4.5.0 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0->scvi-tools) (4.15.0)
# Collecting pytorch-lightning (from lightning>=2.0->scvi-tools)
#   Downloading pytorch_lightning-2.6.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.60.0->scvi-tools) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->scvi-tools) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->scvi-tools) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->scvi-tools) (2025.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (1.5.3)
# Requirement already satisfied: matplotlib>=3.7.5 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (3.10.0)
# Requirement already satisfied: networkx>=2.7.1 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (3.6.1)
# Requirement already satisfied: patsy!=1.0.0 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (1.0.2)
# Requirement already satisfied: pynndescent>=0.5.13 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (0.5.13)
# Requirement already satisfied: seaborn>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (0.13.2)
# Requirement already satisfied: session-info2 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (0.3)
# Requirement already satisfied: statsmodels>=0.14.5 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (0.14.6)
# Requirement already satisfied: umap-learn>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (0.5.9.post2)
# Collecting scikit-misc>=0.1.4 (from scanpy[skmisc]>=1.10->scvi-tools)
#   Downloading scikit_misc-0.5.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->scvi-tools) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools) (3.5.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from ml-collections->scvi-tools) (1.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from pyro-ppl->scvi-tools) (3.4.0)
# Collecting pyro-api>=0.1.1 (from pyro-ppl->scvi-tools)
#   Downloading pyro_api-0.1.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->scvi-tools) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->scvi-tools) (2.19.2)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard->scvi-tools) (1.76.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard->scvi-tools) (3.10)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard->scvi-tools) (5.29.5)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard->scvi-tools) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard->scvi-tools) (3.1.4)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0->scvi-tools) (3.13.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->scvi-tools) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (3.2.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->scvi-tools) (1.3.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard->scvi-tools) (3.0.3)
# Requirement already satisfied: donfig>=0.8 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.11->scvi-tools) (0.8.1.post1)
# Requirement already satisfied: google-crc32c>=1.5 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.11->scvi-tools) (1.7.1)
# Requirement already satisfied: numcodecs>=0.14 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.11->scvi-tools) (0.16.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0->scvi-tools) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0->scvi-tools) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0->scvi-tools) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0->scvi-tools) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0->scvi-tools) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0->scvi-tools) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0->scvi-tools) (1.22.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0->scvi-tools) (3.11)
# Downloading scvi_tools-1.4.1-py3-none-any.whl (641 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 641.1/641.1 kB 32.5 MB/s eta 0:00:00
# Downloading lightning-2.6.0-py3-none-any.whl (845 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 846.0/846.0 kB 37.2 MB/s eta 0:00:00
# Downloading sparse-0.17.0-py2.py3-none-any.whl (259 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.4/259.4 kB 24.7 MB/s eta 0:00:00
# Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 61.1 MB/s eta 0:00:00
# Downloading ml_collections-1.1.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 7.3 MB/s eta 0:00:00
# Downloading mudata-0.3.2-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 3.8 MB/s eta 0:00:00
# Downloading pyro_ppl-1.9.1-py3-none-any.whl (755 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 51.9 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Downloading pyro_api-0.1.2-py3-none-any.whl (11 kB)
# Downloading scikit_misc-0.5.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (182 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.0/183.0 kB 16.2 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.6.0-py3-none-any.whl (849 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.5/849.5 kB 59.7 MB/s eta 0:00:00
# Building wheels for collected packages: docrep
#   Building wheel for docrep (setup.py) ... done
#   Created wheel for docrep: filename=docrep-0.3.2-py3-none-any.whl size=19876 sha256=02a59616e247b6eeff8ea2bdc6d962284f01f47dfedcb387f68c05dbffaa238e
#   Stored in directory: /root/.cache/pip/wheels/d6/19/ee/0a6a1793d91c449563b49ccab57ce52da3e6fab7614836bd8c
# Successfully built docrep
# Installing collected packages: pyro-api, scikit-misc, ml-collections, lightning-utilities, docrep, sparse, torchmetrics, pyro-ppl, mudata, pytorch-lightning, lightning, scvi-tools
# Successfully installed docrep-0.3.2 lightning-2.6.0 lightning-utilities-0.15.2 ml-collections-1.1.0 mudata-0.3.2 pyro-api-0.1.2 pyro-ppl-1.9.1 pytorch-lightning-2.6.0 scikit-misc-0.5.2 scvi-tools-1.4.1 sparse-0.17.0 torchmetrics-1.8.2

# %%
import scvi
import torch

# %%
scvi.__version__
# Out:
# '1.4.1'

# %%
adata_dmso_raw = sc.read_h5ad("/content/drive/MyDrive/ms_singlecell/data/PMS_DMSO_filtered.h5ad")
adata_abt_raw  = sc.read_h5ad("/content/drive/MyDrive/ms_singlecell/data/PMS_ABT_filtered.h5ad")

print(adata_dmso_raw.shape)
print(adata_abt_raw.shape)
# Out:
# (3281, 60623)
# (8987, 60623)

# %%
import numpy as np

common_genes = np.intersect1d(
    adata_dmso_raw.var_names,
    adata_abt_raw.var_names
)

print("Number of common genes:", len(common_genes))
# Out:
# Number of common genes: 60623

# %%
adata_dmso_raw = adata_dmso_raw[:, common_genes].copy()
adata_abt_raw  = adata_abt_raw[:,  common_genes].copy()

print("DMSO shape:", adata_dmso_raw.shape)
print("ABT  shape:", adata_abt_raw.shape)
# Out:
# DMSO shape: (3281, 60623)
# ABT  shape: (8987, 60623)

# %%
adata_dmso_raw.write("adata_dmso_raw_frozen.h5ad")
adata_abt_raw.write("adata_abt_raw_frozen.h5ad")

# %%
scvi.model.SCVI.setup_anndata(adata_dmso_raw)
scvi.model.SCVI.setup_anndata(adata_abt_raw)

# %%
#20 latent dimensions
model_dmso = scvi.model.SCVI(
    adata_dmso_raw,
    n_latent=20
)

model_abt = scvi.model.SCVI(
    adata_abt_raw,
    n_latent=20
)

# %%
model_dmso.train(max_epochs=100)
model_abt.train(max_epochs=100)
# Out:
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# INFO: `Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# INFO: `Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.

# %%
X_dmso_scvi = model_dmso.get_latent_representation()
X_abt_scvi  = model_abt.get_latent_representation()

print("DMSO scVI shape:", X_dmso_scvi.shape)
print("ABT  scVI shape:", X_abt_scvi.shape)
# Out:
# DMSO scVI shape: (3281, 20)
# ABT  scVI shape: (8987, 20)

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
from scipy.spatial.distance import pdist

dist_dmso_scvi = pdist(X_dmso_scvi, metric="euclidean")
dist_abt_scvi  = pdist(X_abt_scvi,  metric="euclidean")

print("DMSO scVI distances:", dist_dmso_scvi.shape)
print("ABT  scVI distances:", dist_abt_scvi.shape)
# Out:
# DMSO scVI distances: (5380840,)
# ABT  scVI distances: (40378591,)

# %%
disp_dmso_scvi = dist_dmso_scvi.mean()
disp_abt_scvi  = dist_abt_scvi.mean()

print("scVI DMSO dispersion:", disp_dmso_scvi)
print("scVI ABT  dispersion:", disp_abt_scvi)
# Out:
# scVI DMSO dispersion: 7.186738149651342
# scVI ABT  dispersion: 7.027669421191334

# %%
from sklearn.neighbors import NearestNeighbors

def compute_compactness(X, k=10):
    nbrs = NearestNeighbors(n_neighbors=k+1).fit(X)
    distances, _ = nbrs.kneighbors(X)
    return distances[:, 1:].mean()

comp_dmso_scvi = compute_compactness(X_dmso_scvi, k=10)
comp_abt_scvi  = compute_compactness(X_abt_scvi,  k=10)

print("scVI DMSO compactness:", comp_dmso_scvi)
print("scVI ABT  compactness:", comp_abt_scvi)
# Out:
# scVI DMSO compactness: 1.5539119039919638
# scVI ABT  compactness: 2.6241633893684244

# %%
print("scVI DMSO mean/std:", dist_dmso_scvi.mean(), dist_dmso_scvi.std())
print("scVI ABT  mean/std:", dist_abt_scvi.mean(),  dist_abt_scvi.std())
# Out:
# scVI DMSO mean/std: 7.186738149651342 2.9847841260363044
# scVI ABT  mean/std: 7.027669421191334 1.7113930283901302

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

# %%
X_dmso = torch.tensor(adata_dmso_n.X, dtype=torch.float32)
X_abt  = torch.tensor(adata_abt_n.X,  dtype=torch.float32)

# %%
class AutoEncoder(nn.Module):
    def __init__(self, input_dim, latent_dim=20):
        super().__init__()

        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, latent_dim)
        )

        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Linear(128, input_dim)
        )

    def forward(self, x):
        z = self.encoder(x)
        x_recon = self.decoder(z)
        return x_recon, z

# %%
def train_autoencoder(X, epochs=50, batch_size=128):
    dataset = TensorDataset(X)
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

    model = AutoEncoder(X.shape[1])
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
    loss_fn = nn.MSELoss()

    for epoch in range(epochs):
        for (batch,) in loader:
            recon, _ = model(batch)
            loss = loss_fn(recon, batch)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

    return model

# %%
ae_dmso = train_autoencoder(X_dmso, epochs=50)
ae_abt  = train_autoencoder(X_abt,  epochs=50)

# %%
with torch.no_grad():
    _, X_dmso_ae = ae_dmso(X_dmso)
    _, X_abt_ae  = ae_abt(X_abt)

X_dmso_ae = X_dmso_ae.numpy()
X_abt_ae  = X_abt_ae.numpy()

print(X_dmso_ae.shape, X_abt_ae.shape)
# Out:
# (3281, 20) (8987, 20)

# %%
from scipy.spatial.distance import pdist

dist_dmso_ae = pdist(X_dmso_ae, metric="euclidean")
dist_abt_ae  = pdist(X_abt_ae,  metric="euclidean")

print("DMSO AE distances:", dist_dmso_ae.shape)
print("ABT  AE distances:", dist_abt_ae.shape)
# Out:
# DMSO AE distances: (5380840,)
# ABT  AE distances: (40378591,)

# %%
disp_dmso_ae = dist_dmso_ae.mean()
disp_abt_ae  = dist_abt_ae.mean()

print("AE DMSO dispersion:", disp_dmso_ae)
print("AE ABT  dispersion:", disp_abt_ae)
# Out:
# AE DMSO dispersion: 32.04225380299988
# AE ABT  dispersion: 25.11343715559013

# %%
from sklearn.neighbors import NearestNeighbors

def compute_compactness(X, k=10):
    nbrs = NearestNeighbors(n_neighbors=k+1).fit(X)
    dists, _ = nbrs.kneighbors(X)
    return dists[:, 1:].mean()

comp_dmso_ae = compute_compactness(X_dmso_ae, k=10)
comp_abt_ae  = compute_compactness(X_abt_ae,  k=10)

print("AE DMSO compactness:", comp_dmso_ae)
print("AE ABT  compactness:", comp_abt_ae)
# Out:
# AE DMSO compactness: 8.602520816241121
# AE ABT  compactness: 8.401924006920629

# %%
print("AE DMSO mean/std:", dist_dmso_ae.mean(), dist_dmso_ae.std())
print("AE ABT  mean/std:", dist_abt_ae.mean(),  dist_abt_ae.std())
# Out:
# AE DMSO mean/std: 32.04225380299988 20.794785339311627
# AE ABT  mean/std: 25.11343715559013 12.302529003397849
